# %%
import time
#import numpy as np
import random

# %%
arr = [random.randint(1, 100) for i in range(10)]
arr
# Out:
# [74, 9, 17, 35, 12, 25, 63, 77, 28, 50]

# %%
clock = time.time()
start_time = clock
#print("Start:", start_time)
#arg_x = np.argmax(arr)
#for arg(x) in arr:\
eachtime = []
for i in range(2, len(arr)):
    key = arr[i]
    j = i - 1
    #eachtime.append(time.time())
    
    
    while j>=0 and key < arr[j]:
        arr[j+1] = arr[j]
        arr[j]=key
        
        
        j -= 1
    arr[j+1] = key
    print(arr)
    #print("time:", eachtime)
end_time = time.time()
#print("End:", end_time)
print("Duration:", end_time - start_time)
print("time:", eachtime)  
print(arr)
# Out:
# [74, 9, 12, 17, 25, 28, 35, 50, 63, 77]
# [74, 9, 12, 17, 25, 28, 35, 50, 63, 77]
# [74, 9, 12, 17, 25, 28, 35, 50, 63, 77]
# [74, 9, 12, 17, 25, 28, 35, 50, 63, 77]
# [74, 9, 12, 17, 25, 28, 35, 50, 63, 77]
# [74, 9, 12, 17, 25, 28, 35, 50, 63, 77]
# [74, 9, 12, 17, 25, 28, 35, 50, 63, 77]
# [74, 9, 12, 17, 25, 28, 35, 50, 63, 77]
# Duration: 0.0006771087646484375
# time: [1736261035.5939927, 1736261035.5946698, 1736261035.5946698, 1736261035.5946698, 1736261035.5946698, 1736261035.5946698, 1736261035.5946698, 1736261035.5946698]
# [74, 9, 12, 17, 25, 28, 35, 50, 63, 77]

# %%
clock = time.time()

start_time = time.time()
newarr = sorted(arr)   
print(arr)
end_time = time.time()
#print("End:", end_time)
print("Duration:", end_time - start_time)
# Out:
# [74, 9, 12, 17, 25, 28, 35, 50, 63, 77]
# Duration: 0.004837989807128906

# %%
import matplotlib.pyplot as plt
plot = plt.plot(eachtime)
